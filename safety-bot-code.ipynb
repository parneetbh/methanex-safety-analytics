# %%
import pandas as pd

df = pd.read_excel("base_reports.xlsx")

# %%
df["combined_text"] = (
    df["what_happened"].fillna("") + " " +
    df["what_could_have_happened"].fillna("") + " " +
    df["why_did_it_happen"].fillna("") + " " +
    df["causal_factors"].fillna("") + " " +
    df["what_went_well"].fillna("") + " " +
    df["lessons_to_prevent"].fillna("")
)

# %%
df["combined_text"] = df["combined_text"].astype(str)

# %%
import vertexai
from vertexai.preview.language_models import TextEmbeddingModel

vertexai.init(
    project="methanex-safety",
    location="us-central1"
)

embedding_model = TextEmbeddingModel.from_pretrained(
    "text-embedding-004"
)
# Out:
# C:\Users\parne\anaconda3\envs\safety-ai\lib\site-packages\google\api_core\_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# C:\Users\parne\anaconda3\envs\safety-ai\lib\site-packages\google\api_core\_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.resourcemanager_v3 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.resourcemanager_v3 past that date.
#   warnings.warn(message, FutureWarning)

# %%
embeddings = []

batch_size = 20

texts = df["combined_text"].tolist()

for i in range(0, len(texts), batch_size):
    batch = texts[i:i+batch_size]

    response = embedding_model.get_embeddings(batch)

    for emb in response:
        embeddings.append(emb.values)

    print(f"Processed {i + len(batch)} / {len(texts)}")
# Out:
# Processed 20 / 196
# Processed 40 / 196
# Processed 60 / 196
# Processed 80 / 196
# Processed 100 / 196
# Processed 120 / 196
# Processed 140 / 196
# Processed 160 / 196
# Processed 180 / 196
# Processed 196 / 196

# %%
import chromadb

client = chromadb.PersistentClient(path="./chroma_db")

collection = client.get_or_create_collection(
    name="safety_incidents"
)

# %%
for row, emb in zip(df.itertuples(), embeddings):
    collection.add(
        documents=[row.combined_text],
        ids=[str(row.case_id)],
        embeddings=[emb]
    )

# %% [markdown]
# **Test Retrieval**

# %%
query = "office slip or trip incident"
query_embedding = embedding_model.get_embeddings([query])[0].values

# %%
results = collection.query(
    query_embeddings=[query_embedding],
    n_results=5
)

# %%
context = ""

for i, doc in enumerate(results["documents"][0]):
    context += f"\nIncident {i+1}:\n{doc}\n"

# %%
prompt = f"""
You are a safety knowledge assistant for industrial operations.

Answer ONLY using the incidents below.
Do not add external safety advice or assumptions.

Summarize in three sections:

1. Common Causes
2. Typical Risks or Escalation Potential
3. Prevention Lessons Observed

Incidents:
{context}
"""

# %% [markdown]
# **Adding Gemini**

# %%
pip install --upgrade google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (0.8.6)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-generativeai) (2.29.0)
# Requirement already satisfied: google-api-python-client in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-generativeai) (2.190.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-generativeai) (2.48.0)
# Requirement already satisfied: protobuf in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-generativeai) (5.29.6)
# Requirement already satisfied: pydantic in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-generativeai) (2.12.5)
# Requirement already satisfied: tqdm in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-generativeai) (4.67.3)
# Requirement already satisfied: typing-extensions in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.27.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-api-core->google-generativeai) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.78.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (3.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-api-python-client->google-generativeai) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-api-python-client->google-generativeai) (0.3.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from pydantic->google-generativeai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\parne\anaconda3\envs\safety-ai\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai

client = genai.Client(
    vertexai=True,
    project="methanex-safety",
    location="us-central1"
)

response = client.models.generate_content(
    model="gemini-2.0-flash",  # updated model
    contents=prompt
)

print(response.text)
# Out:
# Here is a summary of the incidents, based only on the information provided.
#
# ### 1. Common Causes
#
# *   **Inadequate Electrical Equipment Management:** Lack of routine inspections for cords and equipment, improper installation, and use of unapproved personal devices.
# *   **Poor Cable Routing and Management:** Cables obstructing walkways, tangled bundles, no defined pathways, and cords bent in tight spaces.
# *   **Insufficient Risk Assessment:** Incomplete isolation planning, missing circuits, overlooking combined risks (electrical, falls, dropped objects), and inadequate contractor onboarding.
# *   **Poor Housekeeping:** Accumulated items under desks, stacked materials on table edges, and lack of clear ownership for shared area maintenance.
# *   **Workplace Layout:** Congested areas, limited space, and inadequate lighting beneath desks.
# *   **Rushing/Multitasking:** Employees multitasking, rushing, and assuming isolations are complete without verification.
#
# ### 2. Typical Risks or Escalation Potential
#
# *   **Electrical Shock:** From exposed conductors, damaged cords, or partially energized circuits. This could lead to burns, cardiac injury, ventricular fibrillation, or falls due to muscle reaction.
# *   **Falls:** Tripping on cables, slipping on unsecured floor protectors, or falling from ladders. Potential for head trauma, spinal injury, or other serious harm.
# *   **Dropped Objects:** Tools falling from ladders, potentially striking nearby individuals.
# *   **Fire Hazards:** Arcing from damaged cords, ignition of dust or debris, and potential for localized electrical fires.
# *   **Secondary Incidents:** Other employees tripping on cables, exposure to live conductors, or further equipment damage.
# *   **Escalation:** Concussion, electrical burn, serious shock, head/spinal injury, fire.
#
# ### 3. Prevention Lessons Observed
#
# *   **Clear Walkways & Storage:** Maintain clear walkways, store materials away from edges, and manage under-desk storage.
# *   **Electrical Safety Practices:** Routine inspections of electrical equipment, proper cable routing, and strict adherence to electrical isolation procedures.
# *   **Thorough Risk Assessment:** Detailed Job Hazard Analysis (JHA) addressing combined risks, and specific hazard briefings for contractors.
# *   **Dropped Object Prevention:** Tethering tools when working at height, creating exclusion zones, and proper ladder placement.
# *   **Power Isolation Verification:** Verifying zero energy at the exact work location, even with permits.
# *   **Equipment Inspection:** Cable integrity checks and inspections of electrical equipment.
# *   **Incident Reporting & Response:** Immediate incident reporting, prompt response, and isolation of the area.
# *   **Safe Work Practices:** Safe ladder use, spill-proof mugs, avoiding use of personal power devices without approval, and avoiding multitasking while preparing for meetings.

# %%
def ask_safety_assistant(query):

    query_embedding = embedding_model.get_embeddings([query])[0].values

    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=5
    )

    context = "\n".join(results["documents"][0])

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=context
    )

    return response.text
